# %%
import pandas as pd
import numpy as np
import math

# %%
Train_data = pd.read_csv(r'C:\Users\miriy\Downloads\sonar_train.data',header = None)
Test_data = np.array(pd.read_csv(r'C:\Users\miriy\Downloads\sonar_test.data',header = None))

# %%
def calculateProbability(x, mean, stdev):
    exponent = math.exp(-(math.pow(x-mean,2)/(2*math.pow(stdev,2))))
    return (1 / (math.sqrt(2*math.pi) * stdev)) * exponent

# %%
#Accuracy on Test Data
def accuracy(features):
    n = len(Test_data)
    count = 0
    for i in range(n):
        r = Test_data[i,:]
        p1 = 1
        p2 = 1
        for j in features:
            mean = data_summary[1][j]['mean']
            std = data_summary[1][j]['sd']
            p1 = p1 * calculateProbability(r[j], mean, std)
            mean = data_summary[2][j]['mean']
            std = data_summary[2][j]['sd']
            p2 = p2 * calculateProbability(r[j], mean, std)
        if p1 > p2:
            if r[m] == 1:
                count += 1
        else:
            if r[m] == 2:
                count += 1
            
    test_accuracy = count/n * 100
    return test_accuracy 


def computeCovarianceMatrix(data):
    mat = data
    m = len(data)
    mean = (data.sum(axis=0))/m
    n = len(data)
    for i in range(n):
        mat[i] = mat[i] - mean
    mat = mat.transpose()
    mat = np.matmul(mat, mat.transpose())
    return mat

# %%
def eigen(matrix): #Method for calculating Eigen Values and Eigen Vectors
    eigenValues, eigenVectors = np.linalg.eig(matrix) 
    idx = eigenValues.argsort()[::-1][0:10]     #[0:6] selects the top 6 eigen values
    eigenVectors = eigenVectors[:, idx]
    return eigenVectors
    
    

def ProbDis(vector):   #Define Probability distribution
    pd = []
    m, n = vector.shape
    for i in range(m):
        v = 0
        for j in range(n):
            v = v+(vector[i, j]**2)
        pd.append(v/n)
    return pd

# %%
m = len(Train_data.columns)-1
data = {}
data[1] = np.array(Train_data.loc[Train_data[m] == 1])
data[2] = np.array(Train_data.loc[Train_data[m] == 2])

data_summary = {}
for key, value in data.items():
    data_k = value
    data_summary[key] = {}
    for i in range(m):
        tree = {}
        tree['mean'] = np.mean(data_k[:, i])
        tree['sd'] = np.std(data_k[:, i])
        data_summary[key][i] = tree

# %%
trainData = np.array(Train_data.iloc[:,0:m])
CovarianceMatrix = computeCovarianceMatrix(trainData)
eigenVectors = eigen(CovarianceMatrix)

# %%
k = 10
s = 20
for i in range(k):
    eg = eigenVectors[:,0:i+1] #Selects the top K eigen Vectors
    pd = ProbDis(eg) #For Calculating Probability Distribution
    for j in range(s):
        sum_acc = 0
        for it in range(100):  #Running over through 100 iterations to determine average accuracy
            f = np.random.choice(m, j+1, p=pd) #Sampling with repetition with a given probability
            features = np.unique(f) #Selecting the unique features
            test_acc = accuracy(features)
            sum_acc += test_acc #Summing up to calculate average accuracy
        avg_testAccuracy = sum_acc/100 #Average accuracy
        print('Error on test data for value of k =',i+1,'and s = ',j+1,'is',100-avg_testAccuracy)
    print('\n')
# Out:
# Error on test data for value of k = 1 and s =  1 is 43.153846153846125
# Error on test data for value of k = 1 and s =  2 is 43.63461538461538
# Error on test data for value of k = 1 and s =  3 is 43.6346153846154
# Error on test data for value of k = 1 and s =  4 is 41.923076923076934
# Error on test data for value of k = 1 and s =  5 is 41.67307692307691
# Error on test data for value of k = 1 and s =  6 is 41.74999999999998
# Error on test data for value of k = 1 and s =  7 is 42.73076923076922
# Error on test data for value of k = 1 and s =  8 is 43.09615384615381
# Error on test data for value of k = 1 and s =  9 is 41.92307692307691
# Error on test data for value of k = 1 and s =  10 is 42.19230769230769
# Error on test data for value of k = 1 and s =  11 is 41.153846153846146
# Error on test data for value of k = 1 and s =  12 is 42.38461538461537
# Error on test data for value of k = 1 and s =  13 is 43.21153846153844
# Error on test data for value of k = 1 and s =  14 is 41.86538461538462
# Error on test data for value of k = 1 and s =  15 is 42.21153846153844
# Error on test data for value of k = 1 and s =  16 is 42.09615384615382
# Error on test data for value of k = 1 and s =  17 is 43.038461538461526
# Error on test data for value of k = 1 and s =  18 is 42.09615384615382
# Error on test data for value of k = 1 and s =  19 is 42.23076923076921
# Error on test data for value of k = 1 and s =  20 is 42.538461538461476
#
#
# Error on test data for value of k = 2 and s =  1 is 46.40384615384618
# Error on test data for value of k = 2 and s =  2 is 42.0
# Error on test data for value of k = 2 and s =  3 is 41.73076923076921
# Error on test data for value of k = 2 and s =  4 is 40.980769230769226
# Error on test data for value of k = 2 and s =  5 is 39.846153846153875
# Error on test data for value of k = 2 and s =  6 is 41.07692307692307
# Error on test data for value of k = 2 and s =  7 is 40.942307692307665
# Error on test data for value of k = 2 and s =  8 is 41.076923076923066
# Error on test data for value of k = 2 and s =  9 is 41.63461538461539
# Error on test data for value of k = 2 and s =  10 is 39.63461538461538
# Error on test data for value of k = 2 and s =  11 is 40.307692307692285
# Error on test data for value of k = 2 and s =  12 is 41.51923076923075
# Error on test data for value of k = 2 and s =  13 is 40.711538461538446
# Error on test data for value of k = 2 and s =  14 is 41.230769230769226
# Error on test data for value of k = 2 and s =  15 is 40.807692307692314
# Error on test data for value of k = 2 and s =  16 is 40.4807692307692
# Error on test data for value of k = 2 and s =  17 is 40.55769230769231
# Error on test data for value of k = 2 and s =  18 is 40.90384615384612
# Error on test data for value of k = 2 and s =  19 is 41.038461538461505
# Error on test data for value of k = 2 and s =  20 is 40.711538461538446
#
#
# Error on test data for value of k = 3 and s =  1 is 45.26923076923078
# Error on test data for value of k = 3 and s =  2 is 42.63461538461539
# Error on test data for value of k = 3 and s =  3 is 41.442307692307686
# Error on test data for value of k = 3 and s =  4 is 41.01923076923076
# Error on test data for value of k = 3 and s =  5 is 40.365384615384585
# Error on test data for value of k = 3 and s =  6 is 40.90384615384615
# Error on test data for value of k = 3 and s =  7 is 40.71153846153847
# Error on test data for value of k = 3 and s =  8 is 39.98076923076921
# Error on test data for value of k = 3 and s =  9 is 41.01923076923074
# Error on test data for value of k = 3 and s =  10 is 40.73076923076922
# Error on test data for value of k = 3 and s =  11 is 40.557692307692285
# Error on test data for value of k = 3 and s =  12 is 40.19230769230768
# Error on test data for value of k = 3 and s =  13 is 41.11538461538462
# Error on test data for value of k = 3 and s =  14 is 40.78846153846152
# Error on test data for value of k = 3 and s =  15 is 39.59615384615382
# Error on test data for value of k = 3 and s =  16 is 40.80769230769227
# Error on test data for value of k = 3 and s =  17 is 40.4807692307692
# Error on test data for value of k = 3 and s =  18 is 40.57692307692307
# Error on test data for value of k = 3 and s =  19 is 40.86538461538461
# Error on test data for value of k = 3 and s =  20 is 39.942307692307715
#
#
# Error on test data for value of k = 4 and s =  1 is 45.49999999999997
# Error on test data for value of k = 4 and s =  2 is 43.15384615384617
# Error on test data for value of k = 4 and s =  3 is 43.07692307692307
# Error on test data for value of k = 4 and s =  4 is 41.3653846153846
# Error on test data for value of k = 4 and s =  5 is 41.03846153846152
# Error on test data for value of k = 4 and s =  6 is 42.076923076923066
# Error on test data for value of k = 4 and s =  7 is 41.499999999999964
# Error on test data for value of k = 4 and s =  8 is 40.538461538461526
# Error on test data for value of k = 4 and s =  9 is 41.24999999999999
# Error on test data for value of k = 4 and s =  10 is 40.65384615384615
# Error on test data for value of k = 4 and s =  11 is 40.7307692307692
# Error on test data for value of k = 4 and s =  12 is 40.9230769230769
# Error on test data for value of k = 4 and s =  13 is 41.269230769230774
# Error on test data for value of k = 4 and s =  14 is 41.34615384615384
# Error on test data for value of k = 4 and s =  15 is 40.557692307692285
# Error on test data for value of k = 4 and s =  16 is 40.74999999999999
# Error on test data for value of k = 4 and s =  17 is 41.13461538461537
# Error on test data for value of k = 4 and s =  18 is 41.53846153846153
# Error on test data for value of k = 4 and s =  19 is 40.74999999999998
# Error on test data for value of k = 4 and s =  20 is 41.05769230769229
#
#
# Error on test data for value of k = 5 and s =  1 is 43.51923076923079
# Error on test data for value of k = 5 and s =  2 is 40.11538461538462
# Error on test data for value of k = 5 and s =  3 is 38.55769230769229
# Error on test data for value of k = 5 and s =  4 is 36.230769230769226
# Error on test data for value of k = 5 and s =  5 is 37.038461538461526
# Error on test data for value of k = 5 and s =  6 is 35.653846153846175
# Error on test data for value of k = 5 and s =  7 is 35.250000000000014
# Error on test data for value of k = 5 and s =  8 is 34.826923076923094
# Error on test data for value of k = 5 and s =  9 is 33.34615384615384
# Error on test data for value of k = 5 and s =  10 is 33.9807692307692
# Error on test data for value of k = 5 and s =  11 is 32.403846153846175
# Error on test data for value of k = 5 and s =  12 is 32.80769230769231
# Error on test data for value of k = 5 and s =  13 is 32.46153846153845
# Error on test data for value of k = 5 and s =  14 is 32.55769230769229
# Error on test data for value of k = 5 and s =  15 is 32.26923076923076
# Error on test data for value of k = 5 and s =  16 is 33.80769230769231
# Error on test data for value of k = 5 and s =  17 is 31.384615384615387
# Error on test data for value of k = 5 and s =  18 is 30.8846153846154
# Error on test data for value of k = 5 and s =  19 is 31.42307692307692
# Error on test data for value of k = 5 and s =  20 is 32.09615384615381
#
#
# Error on test data for value of k = 6 and s =  1 is 43.67307692307695
# Error on test data for value of k = 6 and s =  2 is 40.28846153846154
# Error on test data for value of k = 6 and s =  3 is 37.980769230769255
# Error on test data for value of k = 6 and s =  4 is 38.576923076923066
# Error on test data for value of k = 6 and s =  5 is 37.48076923076925
# Error on test data for value of k = 6 and s =  6 is 35.71153846153844
# Error on test data for value of k = 6 and s =  7 is 36.42307692307693
# Error on test data for value of k = 6 and s =  8 is 36.07692307692312
# Error on test data for value of k = 6 and s =  9 is 33.69230769230771
# Error on test data for value of k = 6 and s =  10 is 34.21153846153851
# Error on test data for value of k = 6 and s =  11 is 34.153846153846175
# Error on test data for value of k = 6 and s =  12 is 33.67307692307692
# Error on test data for value of k = 6 and s =  13 is 33.69230769230769
# Error on test data for value of k = 6 and s =  14 is 32.50000000000003
# Error on test data for value of k = 6 and s =  15 is 32.211538461538524
# Error on test data for value of k = 6 and s =  16 is 32.03846153846155
# Error on test data for value of k = 6 and s =  17 is 31.250000000000014
# Error on test data for value of k = 6 and s =  18 is 33.03846153846155
# Error on test data for value of k = 6 and s =  19 is 32.557692307692264
# Error on test data for value of k = 6 and s =  20 is 32.38461538461539
#
#
# Error on test data for value of k = 7 and s =  1 is 42.28846153846152
# Error on test data for value of k = 7 and s =  2 is 41.38461538461541
# Error on test data for value of k = 7 and s =  3 is 39.480769230769226
# Error on test data for value of k = 7 and s =  4 is 38.30769230769234
# Error on test data for value of k = 7 and s =  5 is 35.903846153846175
# Error on test data for value of k = 7 and s =  6 is 35.63461538461537
# Error on test data for value of k = 7 and s =  7 is 34.30769230769231
# Error on test data for value of k = 7 and s =  8 is 34.19230769230768
# Error on test data for value of k = 7 and s =  9 is 34.21153846153845
# Error on test data for value of k = 7 and s =  10 is 33.673076923076906
# Error on test data for value of k = 7 and s =  11 is 32.42307692307695
# Error on test data for value of k = 7 and s =  12 is 33.249999999999986
# Error on test data for value of k = 7 and s =  13 is 31.67307692307692
# Error on test data for value of k = 7 and s =  14 is 32.94230769230771
# Error on test data for value of k = 7 and s =  15 is 32.57692307692311
# Error on test data for value of k = 7 and s =  16 is 32.46153846153845
# Error on test data for value of k = 7 and s =  17 is 31.942307692307708
# Error on test data for value of k = 7 and s =  18 is 29.269230769230802
# Error on test data for value of k = 7 and s =  19 is 31.673076923076948
# Error on test data for value of k = 7 and s =  20 is 31.057692307692335
#
#
# Error on test data for value of k = 8 and s =  1 is 43.55769230769228
# Error on test data for value of k = 8 and s =  2 is 39.942307692307686
# Error on test data for value of k = 8 and s =  3 is 37.82692307692307
# Error on test data for value of k = 8 and s =  4 is 37.80769230769231
# Error on test data for value of k = 8 and s =  5 is 37.1153846153846
# Error on test data for value of k = 8 and s =  6 is 37.05769230769231
# Error on test data for value of k = 8 and s =  7 is 34.25
# Error on test data for value of k = 8 and s =  8 is 33.69230769230771
# Error on test data for value of k = 8 and s =  9 is 34.59615384615384
# Error on test data for value of k = 8 and s =  10 is 32.903846153846175
# Error on test data for value of k = 8 and s =  11 is 33.98076923076924
# Error on test data for value of k = 8 and s =  12 is 34.269230769230774
# Error on test data for value of k = 8 and s =  13 is 32.46153846153848
# Error on test data for value of k = 8 and s =  14 is 33.26923076923076
# Error on test data for value of k = 8 and s =  15 is 31.788461538461533
# Error on test data for value of k = 8 and s =  16 is 33.80769230769232
# Error on test data for value of k = 8 and s =  17 is 31.692307692307708
# Error on test data for value of k = 8 and s =  18 is 30.384615384615387
# Error on test data for value of k = 8 and s =  19 is 31.057692307692335
# Error on test data for value of k = 8 and s =  20 is 30.21153846153848
#
#
# Error on test data for value of k = 9 and s =  1 is 42.73076923076925
# Error on test data for value of k = 9 and s =  2 is 41.423076923076884
# Error on test data for value of k = 9 and s =  3 is 39.84615384615387
# Error on test data for value of k = 9 and s =  4 is 36.07692307692304
# Error on test data for value of k = 9 and s =  5 is 35.32692307692308
# Error on test data for value of k = 9 and s =  6 is 34.076923076923094
# Error on test data for value of k = 9 and s =  7 is 34.653846153846146
# Error on test data for value of k = 9 and s =  8 is 33.42307692307692
# Error on test data for value of k = 9 and s =  9 is 33.32692307692305
# Error on test data for value of k = 9 and s =  10 is 32.40384615384613
# Error on test data for value of k = 9 and s =  11 is 33.07692307692308
# Error on test data for value of k = 9 and s =  12 is 33.634615384615415
# Error on test data for value of k = 9 and s =  13 is 32.26923076923073
# Error on test data for value of k = 9 and s =  14 is 32.90384615384616
# Error on test data for value of k = 9 and s =  15 is 31.86538461538464
# Error on test data for value of k = 9 and s =  16 is 31.46153846153851
# Error on test data for value of k = 9 and s =  17 is 31.32692307692311
# Error on test data for value of k = 9 and s =  18 is 30.86538461538464
# Error on test data for value of k = 9 and s =  19 is 30.96153846153848
# Error on test data for value of k = 9 and s =  20 is 30.03846153846156
#
#
# Error on test data for value of k = 10 and s =  1 is 41.44230769230771
# Error on test data for value of k = 10 and s =  2 is 39.884615384615415
# Error on test data for value of k = 10 and s =  3 is 38.94230769230769
# Error on test data for value of k = 10 and s =  4 is 37.65384615384615
# Error on test data for value of k = 10 and s =  5 is 37.57692307692309
# Error on test data for value of k = 10 and s =  6 is 35.13461538461539
# Error on test data for value of k = 10 and s =  7 is 35.269230769230774
# Error on test data for value of k = 10 and s =  8 is 33.05769230769231
# Error on test data for value of k = 10 and s =  9 is 34.36538461538464
# Error on test data for value of k = 10 and s =  10 is 32.71153846153848
# Error on test data for value of k = 10 and s =  11 is 33.46153846153847
# Error on test data for value of k = 10 and s =  12 is 33.32692307692308
# Error on test data for value of k = 10 and s =  13 is 32.942307692307665
# Error on test data for value of k = 10 and s =  14 is 31.211538461538467
# Error on test data for value of k = 10 and s =  15 is 31.75000000000003
# Error on test data for value of k = 10 and s =  16 is 32.19230769230768
# Error on test data for value of k = 10 and s =  17 is 32.59615384615381
# Error on test data for value of k = 10 and s =  18 is 31.30769230769232
# Error on test data for value of k = 10 and s =  19 is 31.596153846153854
# Error on test data for value of k = 10 and s =  20 is 31.192307692307708
